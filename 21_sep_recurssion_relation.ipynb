# %% [markdown]
# Calculate
# 𝑇
# (
# 2
# )
# T(2):
#
# 𝑇
# (
# 2
# )
# =
# 3
# 𝑇
# (
# 1
# )
# +
# 12
# ⋅
# 2
# =
# 3
# ⋅
# 27
# +
# 24
# =
# 81
# +
# 24
# =
# 105
# T(2)=3T(1)+12⋅2=3⋅27+24=81+24=105
# So,
# 𝑇
# (
# 2
# )
# =
# 105
# T(2)=105.

# %% [markdown]
# (a)
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 𝑐
# T(n)=T(n−1)+c
# This is a linear recurrence relation, where each term increases by a constant
# 𝑐
# c.
#
# Using the substitution method, expand the recurrence:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 𝑐
# T(n)=T(n−1)+c
# =
# (
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 𝑐
# )
# +
# 𝑐
# =
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 2
# 𝑐
# =(T(n−2)+c)+c=T(n−2)+2c
# Continuing to expand, we get:
#
# =
# 𝑇
# (
# 𝑛
# −
# 𝑘
# )
# +
# 𝑘
# 𝑐
# =T(n−k)+kc
# Setting
# 𝑘
# =
# 𝑛
# k=n, we reach the base case
# 𝑇
# (
# 0
# )
# =
# 𝑇
# (
# 0
# )
# +
# 𝑛
# 𝑐
# T(0)=T(0)+nc. If
# 𝑇
# (
# 0
# )
# =
# 0
# T(0)=0, then the solution is:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# 𝑐
# T(n)=nc
# So,
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 0
# )
# +
# 𝑛
# 𝑐
# T(n)=T(0)+nc.

# %% [markdown]
# (b)
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# T(n)=2T(n/2)+n
# For this recurrence relation, we assume
# 𝑇
# (
# 1
# )
# =
# Θ
# (
# 1
# )
# T(1)=Θ(1) and solve by expanding:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# T(n)=2T(n/2)+n
# Expanding it recursively, we get:
#
# =
# 2
# (
# 2
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑛
# /
# 2
# )
# +
# 𝑛
# =
# 4
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 2
# 𝑛
# =2(2T(n/4)+n/2)+n=4T(n/4)+2n
# =
# 4
# (
# 2
# 𝑇
# (
# 𝑛
# /
# 8
# )
# +
# 𝑛
# /
# 4
# )
# +
# 2
# 𝑛
# =
# 8
# 𝑇
# (
# 𝑛
# /
# 8
# )
# +
# 3
# 𝑛
# =4(2T(n/8)+n/4)+2n=8T(n/8)+3n
# This forms a pattern. At level
# 𝑘
# k, the term is
# 2
# 𝑘
# 𝑇
# (
# 𝑛
# /
# 2
# 𝑘
# )
# +
# 𝑘
# 𝑛
# 2
# k
#  T(n/2
# k
#  )+kn. When
# 𝑛
# /
# 2
# 𝑘
# =
# 1
# n/2
# k
#  =1,
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# k=log
# 2
# ​
#  n, leading to:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# 𝑇
# (
# 1
# )
# +
# 𝑛
# log
# ⁡
# 2
# 𝑛
# =
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑛
# )
# T(n)=nT(1)+nlog
# 2
# ​
#  n=Θ(nlogn)

# %% [markdown]
# (c)
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=2T(n/2)+c
# Using similar expansion steps:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=2T(n/2)+c
# =
# 2
# (
# 2
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑐
# )
# +
# 𝑐
# =
# 4
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 3
# 𝑐
# =2(2T(n/4)+c)+c=4T(n/4)+3c
# =
# 8
# 𝑇
# (
# 𝑛
# /
# 8
# )
# +
# 7
# 𝑐
# =8T(n/8)+7c
# Following the pattern, at level
# 𝑘
# k we have
# 2
# 𝑘
# 𝑇
# (
# 𝑛
# /
# 2
# 𝑘
# )
# +
# (
# 2
# 𝑘
# −
# 1
# )
# 𝑐
# 2
# k
#  T(n/2
# k
#  )+(2
# k
#  −1)c. At the base level
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# k=log
# 2
# ​
#  n, we get:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# 𝑇
# (
# 1
# )
# +
# (
# 𝑛
# −
# 1
# )
# 𝑐
# =
# Θ
# (
# 𝑛
# )
# T(n)=nT(1)+(n−1)c=Θ(n)

# %% [markdown]
# (d)
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=T(n/2)+c
# Expanding this recurrence relation:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=T(n/2)+c
# =
# (
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑐
# )
# +
# 𝑐
# =
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 2
# 𝑐
# =(T(n/4)+c)+c=T(n/4)+2c
# =
# 𝑇
# (
# 𝑛
# /
# 8
# )
# +
# 3
# 𝑐
# =T(n/8)+3c
# At level
# 𝑘
# k,
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# 𝑘
# )
# +
# 𝑘
# 𝑐
# T(n)=T(n/2
# k
#  )+kc. When
# 𝑛
# /
# 2
# 𝑘
# =
# 1
# n/2
# k
#  =1,
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# k=log
# 2
# ​
#  n:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 1
# )
# +
# 𝑐
# log
# ⁡
# 2
# 𝑛
# =
# Θ
# (
# log
# ⁡
# 𝑛
# )
# T(n)=T(1)+clog
# 2
# ​
#  n=Θ(logn)

# %% [markdown]
# (a)
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 1
# T(n)=2T(n−1)+1
# Using the recursive tree approach, expand the recurrence as follows:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 1
# T(n)=2T(n−1)+1
# =
# 2
# (
# 2
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 1
# )
# +
# 1
# =
# 4
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 3
# =2(2T(n−2)+1)+1=4T(n−2)+3
# =
# 4
# (
# 2
# 𝑇
# (
# 𝑛
# −
# 3
# )
# +
# 1
# )
# +
# 3
# =
# 8
# 𝑇
# (
# 𝑛
# −
# 3
# )
# +
# 7
# =4(2T(n−3)+1)+3=8T(n−3)+7
# This forms a pattern: at level
# 𝑘
# k, the term is
# 2
# 𝑘
# 𝑇
# (
# 𝑛
# −
# 𝑘
# )
# +
# (
# 2
# 𝑘
# −
# 1
# )
# 2
# k
#  T(n−k)+(2
# k
#  −1). At the base level,
# 𝑘
# =
# 𝑛
# k=n, we get:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑛
# 𝑇
# (
# 0
# )
# +
# (
# 2
# 𝑛
# −
# 1
# )
# T(n)=2
# n
#  T(0)+(2
# n
#  −1)
# Assuming
# 𝑇
# (
# 0
# )
# T(0) is constant, this yields
# 𝑇
# (
# 𝑛
# )
# =
# Θ
# (
# 2
# 𝑛
# )
# T(n)=Θ(2
# n
#  ).

# %% [markdown]
# (b)
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# T(n)=2T(n/2)+n
# Expanding this with a recursive tree:
#
# Root:
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# T(n)=2T(n/2)+n
# Next Level: Each
# 𝑇
# (
# 𝑛
# /
# 2
# )
# T(n/2) splits as
# 2
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑛
# /
# 2
# 2T(n/4)+n/2.
# Each level adds up to
# 𝑛
# n, and there are
# log
# ⁡
# 2
# 𝑛
# log
# 2
# ​
#  n levels, leading to:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# log
# ⁡
# 2
# 𝑛
# =
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑛
# )
# T(n)=nlog
# 2
# ​
#  n=Θ(nlogn)
